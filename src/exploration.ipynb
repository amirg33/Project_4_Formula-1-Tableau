# %%
import pandas as pd
import numpy as np
from pandas import json_normalize
import requests 
import json
import os
from dotenv import load_dotenv
import time
import sys

# %%
circuits = pd.read_csv("../data/Unprocessed/circuits.csv")
constructor_results = pd.read_csv("../data/Unprocessed/constructor_results.csv")
constructor_standings = pd.read_csv("../data/Unprocessed/constructor_standings.csv")
driver_standings = pd.read_csv("../data/Unprocessed/driver_standings.csv")
drivers = pd.read_csv("../data/Unprocessed/drivers.csv")
lap_times = pd.read_csv("../data/Unprocessed/lap_times.csv")
pit_stops = pd.read_csv("../data/Unprocessed/pit_stops.csv")
qualifying = pd.read_csv("../data/Unprocessed/qualifying.csv")
races = pd.read_csv("../data/Unprocessed/races.csv")
results = pd.read_csv("../data/Unprocessed/results.csv")
seasons = pd.read_csv("../data/Unprocessed/seasons.csv")
sprint_results = pd.read_csv("../data/Unprocessed/sprint_results.csv")
constructors = pd.read_csv("../data/Unprocessed/constructors.csv")

# %%
drivers
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     21  DEV      Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR     Logan    Sargeant  2000-12-31
#
# ...

# %%
# Visualizing the data in order to see what kind of columns I have: 

import pandas as pd

# Dictionary of the CSV files
file_paths = {
    "circuits": "../data/Unprocessed/circuits.csv",
    "constructor_results": "../data/Unprocessed/constructor_results.csv",
    "constructor_standings": "../data/Unprocessed/constructor_standings.csv",
    "driver_standings": "../data/Unprocessed/driver_standings.csv",
    "drivers": "../data/Unprocessed/drivers.csv",
    "lap_times": "../data/Unprocessed/lap_times.csv",
    "pit_stops": "../data/Unprocessed/pit_stops.csv",
    "qualifying": "../data/Unprocessed/qualifying.csv",
    "races": "../data/Unprocessed/races.csv",
    "results": "../data/Unprocessed/results.csv",
    "seasons": "../data/Unprocessed/seasons.csv",
    "sprint_results": "../data/Unprocessed/sprint_results.csv",
    "constructors": "../data/Unprocessed/constructors.csv"
}
columns_df = pd.DataFrame()

# Iterate through the files and add their column names to the DataFrame
for file_name, file_path in file_paths.items():
    # Read the CSV file
    df = pd.read_csv(file_path)  
    # Add the columns to the DataFrame
    columns_df[file_name] = pd.Series(df.columns)

# %%
columns_df
# Out:
#      circuits   constructor_results   constructor_standings  \
# 0   circuitId  constructorResultsId  constructorStandingsId
# 1  circuitRef                raceId                  raceId
# 2        name         constructorId           constructorId
# 3    location                points                  points
# 4     country                status                position
# 5         lat                   NaN            positionText
# 6         lng                   NaN                    wins
# 7         alt                   NaN                     NaN
# 8         url                   NaN                     NaN
#
#     driver_standings      drivers     lap_times     pit_stops     qualifying  \
# 0  driverStandingsId     driverId        raceId        raceId      qualifyId
# 1             raceId    driverRef      driverId      driverId         raceId
# 2           driverId       number           lap          stop       driverId
# ...
